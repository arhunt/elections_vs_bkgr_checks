# %% [markdown]
# # Presidential Elections vs. Background Checks, 2000-2016

# %% [markdown]
# H0 = A larger victory for a Democrat in a presidential election does not correspond to any significant change in the quantity of background checks performed in the following year.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
pres = pd.read_csv("Cleanup/p_all.csv")
bgc = pd.read_csv("Cleanup/b_all.csv")
stategroups = pd.read_csv("Cleanup/stategroups.csv")

# %%
years = [2000,2004,2008,2012,2016]
bgc_all = bgc.loc[bgc["year"].isin(years)]
bgc_all = bgc_all.loc[bgc["state"] != "Total"]
bgc_all = bgc_all.rename(columns={"state":"State","year":"Year"})

# %%
pres_all = pres.loc[pres["State"] != "Total"]

# %%
compare = bgc_all.merge(pres_all)
compare.shape
# Out:
# (255, 11)

# %% [markdown]
# ## All States, 2000-2016

# %%
x_values = compare["PercentD"]
y_values = compare["pct"]

plt.scatter(compare["PercentD"],compare["pct"],s=3)
plt.title("Background Check Increases vs. Democratic Votes for President,\n 2000-2016 - All States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democratic Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()
print(f"The r-squared is {r_value * r_value}")
# Out:
# The r-squared is 0.06367668327929825

# %%
red_states = pd.DataFrame(stategroups.loc[stategroups['Group'] == 'Red'])
blue_states = pd.DataFrame(stategroups.loc[stategroups['Group'] == 'Blue'])
swing_states = pd.DataFrame(stategroups.loc[stategroups['Group'] == 'Swing'])

# %%
blue_results = compare.merge(blue_states)
red_results = compare.merge(red_states)
swing_results = compare.merge(swing_states)

# %% [markdown]
# ## 'Red' States Only

# %% [markdown]
# Those states which voted for the Republican candidate in all 5 presidential elections, 2000-2016

# %%
x_values = red_results["PercentD"]
y_values = red_results["pct"]

plt.scatter(red_results["PercentD"],red_results["pct"],s=3)
plt.title("Background Check Increases vs. Democratic Votes for President,\n 2000-2016 - Red States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democratic Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()
print(f"The r-squared is {r_value * r_value}")
# Out:
# The r-squared is 0.004813825381268843

# %%
x_values = blue_results["PercentD"]
y_values = blue_results["pct"]

plt.scatter(blue_results["PercentD"],blue_results["pct"],s=3)
plt.title("Background Check Increases vs. Democratic Votes for President,\n 2000-2016 - Blue States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democratic Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()
print(f"The r-squared is {r_value * r_value}")
# Out:
# The r-squared is 0.17424172787005654

# %%
x_values = swing_results["PercentD"]
y_values = swing_results["pct"]

plt.scatter(swing_results["PercentD"],swing_results["pct"],s=3)
plt.title("Background Check Increases vs. Democratic Votes for President,\n 2000 thu 2016 - Swing States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democratic Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()
print(f"The r-squared is {r_value * r_value}")
# Out:
# The r-squared is 0.15762105864156795

# %% [markdown]
# # Presidential Elections with a Democratic Winner: 2008, 2012

# %% [markdown]
# H0 = A national victory for a Democrat in a presidential election does not correspond to any significant change in the quantity of background checks performed in the following year, regardless of the political leanings of that state.

# %%
bgc08 = bgc.loc[bgc["year"] == 2008]
pres08 = pres.loc[pres["Year"] == 2008]
bgc12 = bgc.loc[bgc["year"] == 2012]
pres12 = pres.loc[pres["Year"] == 2012]

# %%
bgc_bo = bgc08.append(bgc12, ignore_index=True)
bgc_bo = bgc_bo.loc[bgc_bo["state"] != "Total"]
pres_bo = pres08.append(pres12, ignore_index=True)
pres_bo = pres_bo.loc[pres_bo["State"] != "Total"]
bgc_bo = bgc_bo.rename(columns={"state":"State","year":"Year"})

# %%
compare = bgc_bo.merge(pres_bo)
compare.shape
# Out:
# (102, 11)

# %%
x_values = compare["PercentD"]
y_values = compare["pct"]

plt.scatter(compare["PercentD"],compare["pct"],s=3)
plt.title("Background Check Increases vs. Democrat Votes for President,\n 2008 & 2012 - All States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democrat Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()

# %%
blue_bo = compare.merge(blue_states)
red = compare.merge(red_states)
swing_bo = compare.merge(swing_states)

# %%
x_values = red["PercentD"]
y_values = red["pct"]

plt.scatter(red["PercentD"],red["pct"],s=3)
plt.title("Background Check Increases vs. Democrat Votes for President,\n 2008 & 2012 - Red States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democrat Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()
print(f"The r-squared is {r_value * r_value}")
# Out:
# The r-squared is 0.04266531027667444

# %%
x_values = blue_bo["PercentD"]
y_values = blue_bo["pct"]

plt.scatter(blue_bo["PercentD"],blue_bo["pct"],s=3)
plt.title("Background Check Increases vs. Democratic Votes for President,\n 2008 & 2012 - Blue States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democratic Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
plt.show()
print(f"The r-squared is {r_value * r_value}")
# Out:
# The r-squared is 0.016255799880246623

# %%
x_values = swing_bo["PercentD"]
y_values = swing_bo["pct"]

plt.scatter(swing_bo["PercentD"],swing_bo["pct"],s=3)
plt.title("Background Check Increases vs. Democratic Votes for President,\n 2008 & 2012 - Blue States")
plt.ylabel("Background Check Increases (%)")
plt.xlabel("Democratic Votes for President (%)")
plt.grid()
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(min(x_values)+0.5,min(y_values)),fontsize=14,color="red")
print(f"The r-squared is {r_value * r_value}")
plt.show()
# Out:
# The r-squared is 0.3214668795280368
